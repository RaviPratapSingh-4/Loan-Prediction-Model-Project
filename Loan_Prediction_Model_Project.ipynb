# %%
import pandas as pd

# %% [markdown]
# # Reading Dataset

# %%
df = pd.read_csv(r"C:\Users\RAVI\Videos\Downloads\loan _data_after_feature_enginnering.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    int64
#  9   Loan_Amount_Term   614 non-null    int64
#  10  Credit_History     614 non-null    int64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
#  13  Total_Income       614 non-null    float64
#  14  LTI                614 non-null    float64
#  15  Binning            614 non-null    object
# ...

# %%
columns_to_extract = [
    "ApplicantIncome", 
    "CoapplicantIncome", 
    "LoanAmount", 
    "Loan_Amount_Term", 
    "Credit_History", 
    "Total_Income", 
    "LTI"
]

# %%
x = df[columns_to_extract]

# %%
x
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         128               360
# 1               4583             1508.0         128               360
# 2               3000                0.0          66               360
# 3               2583             2358.0         120               360
# 4               6000                0.0         141               360
# ..               ...                ...         ...               ...
# 609             2900                0.0          71               360
# 610             4106                0.0          40               180
# 611             8072              240.0         253               360
# 612             7583                0.0         187               360
# 613             4583                0.0         133               360
#
#      Credit_History  Total_Income       LTI
# 0                 1        5849.0  2.188408
# ...

# %%
y = df["Loan_Status"]

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size = 0.30, random_state = 4)

# %%
x_train
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 196             8333             3750.0         187               360
# 192             6033                0.0         160               360
# 154             3254                0.0          50               360
# 42              2400                0.0          75               360
# 441             7901             1833.0         180               360
# ..               ...                ...         ...               ...
# 599             5780                0.0         192               360
# 360             4723                0.0          81               360
# 439             7142                0.0         138               360
# 174             4344              736.0          87               360
# 122             2137             8980.0         137               360
#
#      Credit_History  Total_Income       LTI
# 196               1       12083.0  1.547629
# ...

# %%
x_test
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 547             2526             1783.0         145               360
# 239             3315                0.0          96               360
# 166             4583                0.0         112               360
# 209             3418                0.0         127               360
# 157             9538                0.0         187               360
# ..               ...                ...         ...               ...
# 355             3813                0.0         116               180
# 211             3430             1250.0         128               360
# 134             4895                0.0         102               360
# 311             2927             2405.0         111               360
# 210            10000                0.0         214               360
#
#      Credit_History  Total_Income       LTI
# 547               1        4309.0  3.365050
# ...

# %%
from sklearn.preprocessing import StandardScaler
var = StandardScaler()
x_train = var.fit_transform(x_train)
x_test = var.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.3708679 ,  0.84441571,  0.45276385, ...,  0.41101987,
#          0.66288971, -0.92631191],
#        [ 0.04238545, -0.624672  ,  0.14826616, ...,  0.41101987,
#         -0.18102484,  0.36132384],
#        [-0.35450703, -0.624672  , -1.09227997, ...,  0.41101987,
#         -0.56866757, -0.9392046 ],
#        ...,
#        [ 0.20077112, -0.624672  , -0.09984306, ...,  0.41101987,
#         -0.02633042, -0.47791865],
#        [-0.19883492, -0.33633905, -0.67500536, ...,  0.41101987,
#         -0.31395881, -0.73398052],
#        [-0.51403525,  2.89330337, -0.11112076, ..., -2.43297243,
#          0.52814236, -1.29388667]])

# %%
x_test
# Out:
# array([[-0.45847887,  0.07383023, -0.02089922, ...,  0.41101987,
#         -0.42150561,  1.19254674],
#        [-0.34579511, -0.624672  , -0.57350613, ...,  0.41101987,
#         -0.56015868,  0.64561577],
#        [-0.1647013 , -0.624672  , -0.39306306, ...,  0.41101987,
#         -0.38328535,  0.11851467],
#        ...,
#        [-0.12014195, -0.624672  , -0.50583998, ...,  0.41101987,
#         -0.33976447, -0.30125928],
#        [-0.40120867,  0.31750292, -0.40434075, ...,  0.41101987,
#         -0.27880733, -0.30357759],
#        [ 0.60894626, -0.624672  ,  0.75726154, ...,  0.41101987,
#          0.37233202, -0.23569007]])

# %%
logReg = LogisticRegression()
logReg.fit(x_train, y_train)
y_pred = logReg.predict(x_test)

# %%
y_pred
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'N', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
# ...

# %% [markdown]
# # Results:

# %% [markdown]
# # Accuracy Score of the Logistic Regression model

# %%
accuracy_score(y_pred, y_test)
# Out:
# 0.8

# %% [markdown]
# # Confusion Matrix of the Logistic Regression model

# %%
confusion_matrix(y_pred, y_test)
# Out:
# array([[ 26,   2],
#        [ 35, 122]], dtype=int64)

# %% [markdown]
# # Brief on the numerical result

# %% [markdown]
# # the results shows that applicants who have more probability of getting loan have :
# # i- Applicants with higher ApplicantIncome and CoapplicantIncome
# # ii- Individuals with lower Loan-to-Income (LTI) ratios
# # iii- applicants with Good Credit History
# # iv- Applicants requesting a LoanAmount that is reasonable relative to their income and loan term
# # v- Loans with longer repayment periods (Loan_Amount_Term) might be more favorable as they reduce the monthly repayment burden, increasing affordability
